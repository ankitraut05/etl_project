# %%
import pandas as pd

# %%
File_Path = "D:\\Ankit\\Projects\\Python\\Files\\employees.csv"
df = pd.read_csv(File_Path)
df
# Out:
#    emp_id first_name last_name                    email   salary department
# 0     101       John       Doe     john.doe@example.com  50000.0         IT
# 1     102       Jane     Smith   jane.smith@example.com  60000.0    Finance
# 2     103       Mark       NaN   mark.adams@example.com  55000.0         HR
# 3     104      Linda       Lee        linda.lee@example  65000.0         IT
# 4     105      Chris     Evans  chris.evans@example.com      NaN    Finance

# %%
#Remove value
df = df.dropna(subset = ['emp_id', 'email'])
df
# Out:
#    emp_id first_name last_name                    email   salary department
# 0     101       John       Doe     john.doe@example.com  50000.0         IT
# 1     102       Jane     Smith   jane.smith@example.com  60000.0    Finance
# 2     103       Mark       NaN   mark.adams@example.com  55000.0         HR
# 3     104      Linda       Lee        linda.lee@example  65000.0         IT
# 4     105      Chris     Evans  chris.evans@example.com      NaN    Finance

# %%
df["last_name"]=df["last_name"].fillna("Unknown")

# %%
df
# Out:
#    emp_id first_name last_name                    email   salary department
# 0     101       John       Doe     john.doe@example.com  50000.0         IT
# 1     102       Jane     Smith   jane.smith@example.com  60000.0    Finance
# 2     103       Mark   Unknown   mark.adams@example.com  55000.0         HR
# 3     104      Linda       Lee        linda.lee@example  65000.0         IT
# 4     105      Chris     Evans  chris.evans@example.com      NaN    Finance

# %%
df['salary']=df['salary'].fillna(df['salary'].mean())
df
# Out:
#    emp_id first_name last_name                    email   salary department
# 0     101       John       Doe     john.doe@example.com  50000.0         IT
# 1     102       Jane     Smith   jane.smith@example.com  60000.0    Finance
# 2     103       Mark   Unknown   mark.adams@example.com  55000.0         HR
# 3     104      Linda       Lee        linda.lee@example  65000.0         IT
# 4     105      Chris     Evans  chris.evans@example.com  57500.0    Finance

# %%
df['department']=df['department'].str.upper()
df
# Out:
#    emp_id first_name last_name                    email   salary department
# 0     101       John       Doe     john.doe@example.com  50000.0         IT
# 1     102       Jane     Smith   jane.smith@example.com  60000.0    FINANCE
# 2     103       Mark   Unknown   mark.adams@example.com  55000.0         HR
# 3     104      Linda       Lee        linda.lee@example  65000.0         IT
# 4     105      Chris     Evans  chris.evans@example.com  57500.0    FINANCE

# %%
import mysql.connector as sql

mydb = sql.connect(
         host="localhost",
         user="root",
         password = "Ankit@123"
)
mycursor = mydb.cursor()

# %%
mydb = sql.connect(
         host="localhost",
         user="root",
         password = "Ankit@123"
)
mycursor = mydb.cursor()
mycursor.execute("show databases")

for x in mycursor:
  print(x)
# Out:
# ('brainpower_internal',)
# ('employee',)
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('test',)

# %%
mycursor.execute("DROP DATABASE if exists employee")
mycursor.execute("CREATE DATABASE employee")

# %%
mydb = sql.connect(
         host="localhost",
         user="root",
         password = "Ankit@123",
         database = "employee"
)
mycursor = mydb.cursor()

create_table = "CREATE TABLE EMPLOYEE_DETAILS (emp_id int , first_name varchar(255) , last_name varchar(255), email varchar(255) , salary float , department varchar(255))"
mycursor = mydb.cursor()
mycursor.execute(create_table)

# %%
mydb = sql.connect(
         host="localhost",
         user="root",
         password = "Ankit@123",
         database = "employee"
)
mycursor= mydb.cursor()
mycursor.execute("SHOW TABLES")

for i in mycursor:
    print(i)
# Out:
# ('employee_details',)

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM EMPLOYEE_DETAILS")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)

# %%
pip install sqlalchemy pymysql

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(f"mysql+pymysql://root:Ankit@123@localhost:3306/employee")

# %%
df.to_sql(
    name="EMPLOYEE_DETAILS",     # table name
    con=engine,
    if_exists="append",  # "fail" | "replace" | "append"
    index=False           # don’t write DataFrame index as column
)
# Out:
# 5

# %%
engine.dispose()

# %%
df
# Out:
#    emp_id first_name last_name                    email   salary department
# 0     101       John       Doe     john.doe@example.com  50000.0         IT
# 1     102       Jane     Smith   jane.smith@example.com  60000.0    FINANCE
# 2     103       Mark   Unknown   mark.adams@example.com  55000.0         HR
# 3     104      Linda       Lee        linda.lee@example  65000.0         IT
# 4     105      Chris     Evans  chris.evans@example.com  57500.0    FINANCE

# %%
mode = df['salary'].mode()
mode
# Out:
# 0    50000.0
# 1    55000.0
# 2    57500.0
# 3    60000.0
# 4    65000.0
# Name: salary, dtype: float64

# %%
df['department'].str.upper()
# Out:
# 0         IT
# 1    FINANCE
# 2         HR
# 3         IT
# 4    FINANCE
# Name: department, dtype: object

# %%
import pandas as pd
File_Path = "D:\\Ankit\\Projects\\Python\\Files\\employees.csv"
df = pd.read_csv(File_Path)
df
# Out:
#    emp_id first_name last_name                    email     salary  \
# 0   101.0       John       Doe     john.doe@example.com    50000.0
# 1   102.0       Jane     Smith   jane.smith@example.com    60000.0
# 2   103.0       Mark       NaN   mark.adams@example.com    55000.0
# 3   104.0      Linda       Lee        linda.lee@example    65000.0
# 4   105.0      Chris     Evans  chris.evans@example.com        NaN
# 5   104.0      Linda       Lee        linda.lee@example    65000.0
# 6   106.0      Ankit      Raut          ankit@gmail.com  1000000.0
# 7   107.0   Nachiket      Save                nachi.com   700000.0
# 8     NaN      Sumit     Pawar          sumit@gmail.com   800000.0
# 9   109.0     Manish     Dhuri                      NaN   900000.0
#
#     department
# 0           IT
# 1      Finance
# 2           HR
# 3           IT
# 4      Finance
# 5           IT
# 6           IT
# 7  Photography
# 8           IT
# 9          FNB

# %%
df['emp_id'][0]
# Out:
# 101

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      5 non-null      int64
#  1   first_name  5 non-null      object
#  2   last_name   4 non-null      object
#  3   email       5 non-null      object
#  4   salary      4 non-null      float64
#  5   department  5 non-null      object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 368.0+ bytes

# %%
len(df)
# Out:
# 5

# %%
for x in df:
    print(x)
# Out:
# emp_id
# first_name
# last_name
# email
# salary
# department

# %%
for i in range(len(df)):
    print(df['emp_id'][i])
# Out:
# 101
# 102
# 103
# 104
# 105

# %%
for i in range(len(df)):
    print(df.iloc[i]['emp_id'])
    
# for i in range(len(df)):
#     print(df.loc[i])
# Out:
# 101
# 102
# 103
# 104
# 105

# %%
for i in df['emp_id']:
    print(i)
# Out:
# 101
# 102
# 103
# 104
# 105

# %%
df
# Out:
#    emp_id first_name last_name                    email   salary department
# 0     101       John       Doe     john.doe@example.com  50000.0         IT
# 1     102       Jane     Smith   jane.smith@example.com  60000.0    Finance
# 2     103       Mark       NaN   mark.adams@example.com  55000.0         HR
# 3     104      Linda       Lee        linda.lee@example  65000.0         IT
# 4     105      Chris     Evans  chris.evans@example.com      NaN    Finance
# 5     104      Linda       Lee        linda.lee@example  65000.0         IT

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#    emp_id first_name last_name                    email   salary department
# 0     101       John       Doe     john.doe@example.com  50000.0         IT
# 1     102       Jane     Smith   jane.smith@example.com  60000.0    Finance
# 2     103       Mark       NaN   mark.adams@example.com  55000.0         HR
# 3     104      Linda       Lee        linda.lee@example  65000.0         IT
# 4     105      Chris     Evans  chris.evans@example.com      NaN    Finance

# %%
df
# Out:
#    emp_id first_name last_name                    email     salary  \
# 0   101.0       John       Doe     john.doe@example.com    50000.0
# 1   102.0       Jane     Smith   jane.smith@example.com    60000.0
# 2   103.0       Mark       NaN   mark.adams@example.com    55000.0
# 3   104.0      Linda       Lee        linda.lee@example    65000.0
# 4   105.0      Chris     Evans  chris.evans@example.com        NaN
# 5   104.0      Linda       Lee        linda.lee@example    65000.0
# 6   106.0      Ankit      Raut          ankit@gmail.com  1000000.0
# 7   107.0   Nachiket      Save                nachi.com   700000.0
# 8     NaN      Sumit     Pawar          sumit@gmail.com   800000.0
# 9   109.0     Manish     Dhuri                      NaN   900000.0
#
#     department
# 0           IT
# 1      Finance
# 2           HR
# 3           IT
# 4      Finance
# 5           IT
# 6           IT
# 7  Photography
# 8           IT
# 9          FNB

# %%
df = df.dropna(subset = ['emp_id','email'])

# %%
df
# Out:
#    emp_id first_name last_name                    email     salary  \
# 0   101.0       John       Doe     john.doe@example.com    50000.0
# 1   102.0       Jane     Smith   jane.smith@example.com    60000.0
# 2   103.0       Mark       NaN   mark.adams@example.com    55000.0
# 3   104.0      Linda       Lee        linda.lee@example    65000.0
# 4   105.0      Chris     Evans  chris.evans@example.com        NaN
# 5   104.0      Linda       Lee        linda.lee@example    65000.0
# 6   106.0      Ankit      Raut          ankit@gmail.com  1000000.0
# 7   107.0   Nachiket      Save                nachi.com   700000.0
#
#     department
# 0           IT
# 1      Finance
# 2           HR
# 3           IT
# 4      Finance
# 5           IT
# 6           IT
# 7  Photography

# %%
df['email'][7]
# Out:
# 'nachi.com'

# %%
df['email'][7] ='nachi#gmail.com'
# Out:
# <ipython-input-78-4886711c1705>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['email'][7] ='nachi#gmail.com'

# %%
df
# Out:
#    emp_id first_name last_name                    email     salary  \
# 0   101.0       John       Doe     john.doe@example.com    50000.0
# 1   102.0       Jane     Smith   jane.smith@example.com    60000.0
# 2   103.0       Mark       NaN   mark.adams@example.com    55000.0
# 3   104.0      Linda       Lee        linda.lee@example    65000.0
# 4   105.0      Chris     Evans  chris.evans@example.com        NaN
# 5   104.0      Linda       Lee        linda.lee@example    65000.0
# 6   106.0      Ankit      Raut          ankit@gmail.com  1000000.0
# 7   107.0   Nachiket      Save          nachi#gmail.com   700000.0
#
#     department
# 0           IT
# 1      Finance
# 2           HR
# 3           IT
# 4      Finance
# 5           IT
# 6           IT
# 7  Photography

# %%
df.to_csv("D:\\Ankit\\Projects\\Python\\Files\\employees.csv")

# %%
import pandas as pd
File_Path = "D:\\Ankit\\Projects\\Python\\Files\\employees.csv"
df = pd.read_csv(File_Path)
df
# Out:
#    Unnamed: 0  emp_id first_name last_name                    email  \
# 0           0   101.0       John       Doe     john.doe@example.com
# 1           1   102.0       Jane     Smith   jane.smith@example.com
# 2           2   103.0       Mark       NaN   mark.adams@example.com
# 3           3   104.0      Linda       Lee        linda.lee@example
# 4           4   105.0      Chris     Evans  chris.evans@example.com
# 5           5   104.0      Linda       Lee        linda.lee@example
# 6           6   106.0      Ankit      Raut          ankit@gmail.com
# 7           7   107.0   Nachiket      Save          nachi#gmail.com
#
#       salary   department
# 0    50000.0           IT
# 1    60000.0      Finance
# 2    55000.0           HR
# 3    65000.0           IT
# 4        NaN      Finance
# 5    65000.0           IT
# 6  1000000.0           IT
# 7   700000.0  Photography

# %%
df
# Out:
#    Unnamed: 0  emp_id first_name last_name                    email  \
# 0           0   101.0       John       Doe     john.doe@example.com
# 1           1   102.0       Jane     Smith   jane.smith@example.com
# 2           2   103.0       Mark       NaN   mark.adams@example.com
# 3           3   104.0      Linda       Lee        linda.lee@example
# 4           4   105.0      Chris     Evans  chris.evans@example.com
# 5           5   104.0      Linda       Lee        linda.lee@example
# 6           6   106.0      Ankit      Raut          ankit@gmail.com
# 7           7   107.0   Nachiket      Save          nachi#gmail.com
#
#       salary   department
# 0    50000.0           IT
# 1    60000.0      Finance
# 2    55000.0           HR
# 3    65000.0           IT
# 4        NaN      Finance
# 5    65000.0           IT
# 6  1000000.0           IT
# 7   700000.0  Photography

# %%
df[df['email'].str.contains('@')]
# Out:
#    Unnamed: 0  emp_id first_name last_name                    email  \
# 0           0   101.0       John       Doe     john.doe@example.com
# 1           1   102.0       Jane     Smith   jane.smith@example.com
# 2           2   103.0       Mark       NaN   mark.adams@example.com
# 3           3   104.0      Linda       Lee        linda.lee@example
# 4           4   105.0      Chris     Evans  chris.evans@example.com
# 5           5   104.0      Linda       Lee        linda.lee@example
# 6           6   106.0      Ankit      Raut          ankit@gmail.com
#
#       salary department
# 0    50000.0         IT
# 1    60000.0    Finance
# 2    55000.0         HR
# 3    65000.0         IT
# 4        NaN    Finance
# 5    65000.0         IT
# 6  1000000.0         IT

# %%
import pandas as pd
File = "unwanted_employees_data.csv"
File_Path = f"D:\Ankit\Projects\Python\Files\{File}"
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
df = pd.read_csv(File_Path)
df
# Out:
#       emp_id first_name last_name                      email     salary  \
# 0          1     Ppebba    Whedkx   ppebba.whedkxexample.com   60806.91
# 1          2     Lpplpo    Gpivyf  lpplpo.gpivyf@example.com        NaN
# 2          3     Qipklr    Sxhwuk   qipklr.sxhwukexample.com  104512.34
# 3          4     Sovvpm    Vmpaks  sovvpm.vmpaks@example.com        NaN
# 4          5     Bddfct    Rxghzz  bddfct.rxghzz@example.com        NaN
# 5          6     Hqgeqa    Apjdba  hqgeqa.apjdba@example.com        NaN
# 6          7     Dsatte    Nophsh   dsatte.nophshexample.com   82150.52
# 7          8     Fuoxhe    Xrlkyf  fuoxhe.xrlkyf@example.com        NaN
# 8          9     Cjzvuc    Yfiuou  cjzvuc.yfiuou@example.com   47350.06
# 9         10     Emgeqc    Vhsepb  emgeqc.vhsepb@example.com        NaN
# 10        11     Senvcq    Secedr  senvcq.secedr@example.com        NaN
# 11        12     Odtekb    Pfakzd  odtekb.pfakzd@example.com        NaN
# ...

# %%
import mysql.connector as sql
con = sql.connect(
    host='localhost',
    user='root',
    password='Ankit@123',
    database='employee'
)
cursor=con.cursor()

def insert(df):
    query = "insert into employee_details (emp_id,first_name,last_name,email,salary,department) values(%s,%s,%s,%s,%s,%s)"
    values = [
                int(df['emp_id']),df['first_name'],df['last_name'],df['email'],float(df['salary']),df['department']
    ]
    cursor.execute(query,values)
    con.commit()
    print(f'inserted {cursor.rowcount} record')
    
def update(df):
    id = df['emp_id']
    query = f"update employee_details set first_name=%s , last_name=%s , email=%s , salary=%s , department=%s where emp_id=%s"
    values = [
        df['first_name'],df['last_name'],df['email'],float(df['salary']),df['department'],int(id)
    ]
    cursor.execute(query,values)
    con.commit()
    print(f'updated {cursor.rowcount} record')

for x in range(len(df)):
    #print(df.iloc[x]['emp_id'])
    emp_id = df.iloc[x]['emp_id']
    query = f'SELECT count(1) FROM EMPLOYEE_DETAILS WHERE EMP_ID={emp_id}'
    #print(query)
    cursor.execute(query)
    (result,) = cursor.fetchone()
    
    if result == 0:
        insert(df.iloc[x])
        #print('insert')
    else:
        update(df.iloc[x])
        #print('update')
